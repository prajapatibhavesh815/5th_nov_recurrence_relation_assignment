# %% [markdown]
# 1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

# %%
 ##To find the value of T(2) for the recurrence relation T(n)=3T(n-1) + 12n ,with
#the initial condition T(0) = 5, we can use the recurrence relation iteratively.
 #                             T(1) = 3T(0) + 12(1)
 #                                  = 3(5)  + 12
 #                                  = 15  + 12 
 #                                  = 27

#s let's find T(2):
#                              T(2) = 3T(1) + 12(2)
#                                   = 3(27) + 24
#                                   = 81 + 24
#                                   = 105
#Therfore, the value of T(2) for the given recurrence relation is 105 """

# %% [markdown]
# 2. Given a recurrence relation, solve it using the substitution method:
#
# (a). T(n) = T(n-1) + c

# %%
#To solve the recurrence relation T(n)=T(n−1)+c using the substitution method, let's express it in terms of smaller subproblems until we reach the base case.
#The recurrence relation is:
#                    T(n)=T(n−1)+c
#s, let's expand it:
#                    T(n)=T(n−2)+c+c
#                    T(n)=T(n−3)+c+c+c
#Continuing this pattern, we can express T(n) in terms of T(n−k) as:
#                    T(n)=T(n−k)+k⋅c
#We continue until we reach the base case, which is when n−k=0, or k=n:
 #                   T(n)=T(0)+n⋅c
#s, substitute the base case T(0) with its given value:
#                    T(n)=T(0)+n⋅c
#Since T(0) is given as an initial condition, you can substitute the specific value to get the final solution.
#For example, if T(0)=5, the solution is:
 #                   T(n)=5+n⋅c
#So, the solution to the recurrence relation T(n)=T(n−1)+c using the substitution method is T(n)=5+n⋅c, where c is a constant.

# %% [markdown]
#   2. Given a recurrence relation, solve it using the substitution method:
#
#   b. T(n) = 2T(n/2) + n

# %%
#To solve the recurrence relation T(n)= 2T(n/2)+n using the substitution method, we'll use repeated substitution and look for a pattern.
#First Substitution:
#             T(n)=2T(n/2)+n 
#Second Substitution:
#             T(n/2)=2T(n/4)+n/2
#Substitute this back into the original equation:

#             T(n)=2(2T(n/4)+n/2
#Simplify:
#             T(n)=4T(n/4)+2n
#Third Substitution:
#             T(n/4)=2T(n/8)+n/4
 #Substitute this into the second substitution:
#             T(n)=4(2T(n/8)+(n/4))+2n
#Simplify:

#             T(n)=8T(n/8)+3n

#After k steps, we get:
#            T(n)=2T(n/2k)+kn

#s, we need to find the value of k when n/2k = 1, which gives us k=log2n.

#Substitute k=log2n into the expression: 
             #T(n)= 2log2nT(1) + nlog2n

#Simplify further using the fact that 

#             T(n)=nT(1)+nlog 

#If you have an initial condition T(1), you can substitute it in. If not, you can leave the solution in this form.

# %% [markdown]
# 2. Given a recurrence relation, solve it using the substitution method:
#
# c. T(n) = 2T(n/2) + c

# %%
#To solve the recurrence relation T(n)= 2T(n/2)+c using the substitution method, we'll use repeated substitution and look for a pattern.
#First Substitution:
#             T(n)=2T(n/2)+c 
#Second Substitution:
#             T(n/2)=2T(n/4)+c
#Substitute this back into the original equation:

#             T(n)=2(2T(n/4+c)+c
#Simplify:
#             T(n)=4T(n/4)+3c
#Third Substitution:
#             T(n/4)=2T(n/8)+c
 #Substitute this into the second substitution:
#             T(n)=4(2T(n/8)+c)+3c
#Simplify:

#             T(n)=8T(n/8)+7c

#After k steps, we get:
#            T(n)=2T(n/2k)+kc

#now, we need to find the value of k when n/2k = 1, which gives us k=log2n.

#Substitute k=log2n into the expression: 
             #T(n)= 2log2nT(1) + log2n.c

#Simplify further using the fact that 

#             T(n)=nT(1)+log2n.c 

#If you have an initial condition T(1), you can substitute it in. If not, you can leave the solution in this form.

# %% [markdown]
# 2. Given a recurrence relation, solve it using the substitution method:
#
# d. T(n) = T(n/2) + c

# %%
#To solve the recurrence relation T(n) = T(n/2)+c using the substitution method, let's express it in terms of smaller subproblems until we reach the base case.

#First Substitution:
           #T(n)=T(n/2)+c

#Second Substitution:

           #T(n/2)=T(n/4)+c
#Substitute this back into the original equation:
           #T(n)=T(n/4)+2c

#Third Substitution:
           #T(n/4)=T(n/8)+c
#Substitute this into the second substitution:

           #T(n)=T(n/8)+3c

#After k steps, we get:

           #T(n)=T(n/2k)+kc

#Now, we need to find the value of k when n/2k=1, which gives us k=log2n.

#Substitute k = log2n into the expression:

           #T(n)=T(1)+log2n⋅c

#If you have an initial condition T(1), you can substitute it in. If not, you can leave the solution in this form. 
#So, the solution to the recurrence relation T(n)= T(n/2)+c using the substitution method is T(n)= T(1) + log2n.c

# %% [markdown]
# 3. Given a recurrence relation, solve it using the recursive tree approach:
#
# a. T(n) = 2T(n-1) +1

# %%
#To solve this recurrence relation T(n)=2T(n-1)+1 using the recursive tree approach we can visualize calls as a tree.
#Each level of the tree represents a different value of n, and each node represents a subproblem.
#the recursive tree for this recurrence relation can be represented as follows:

#T(n)
#  |
# +-- 2T(n-1) + 1
#         |
#         +-- 2T(n-2) + 1
#                |
#                +-- 2T(n-3) + 1
#                       |
#                       +-- ...
# Now,let's analyze the strucure of the tree and identify a pattern.

#1.First level(n):
          # T(n)=2T(n-1)+1

#2. Second level(n-1):
           # T(n-1)=2T(n-2)+1
    #substitute this into the first level:
          #T(n)=2(2T(n-2)+1)+1=4T(n-2)+3

#3. Third level(n-2):
           #T(n-2)=2T(n-3)+1

    #substitute this into the second level :
           #T(n-1)=2(2T(n-3)+1)+1=4T(n-3)+3
    #substitute this into the first level:
           #T(n)=2(4T(n-3)+3)+1=8T(n-3)+7
   #After k levels, we can generalize the pattern:

          #T(n)=2kT(n-k)+(2k-1)

#Now, we need to find when n-k=0 to each the base cash. This gives us k = n.

   #Substitute k=n into the expression:
          #T(n)=2nT(0)+(2n-1)

# if you have in initial condition T(0), you can substitute it in. if not, you canm leave the solution in this form. 
#So,the solution to the recurrence relation T(n)=2T(n-1)+1 using the recursive tree approach is T(n)=2nT(0)+(2n-1),where T(0)is the initial condition.

# %% [markdown]
# 3. Given a recurrence relation, solve it using the recursive tree approach:
#
# b. T(n) = 2T(n/2) + n

# %%
#To solve this recurrence relation T(n)=2T(n/2)+n using the recursive tree approach we can visualize calls as a tree.
#Each level of the tree represents a different value of n, and each node represents a subproblem.
#the recursive tree for this recurrence relation can be represented as follows:

#T(n)
#  |
# +-- 2T(n/2) + n
#         |
#         +-- 2T(n/4) + n/2
#                |
#                +-- 2T(n/8) + n/4
#                       |
#                       +-- ...
# Now,let's analyze the strucure of the tree and identify a pattern.

#1.First level(n):
          # T(n)=2T(n/2)+n

#2. Second level(n-1):
           # T(n/2)=2T(n/4)+n/2
    #substitute this into the first level:
          #T(n)=2(2T(n/4)+n/2)+n=4T(n/4)+n

#3. Third level(n-2):
           #T(n/4)=2T(n/8)+n/4

    #substitute this into the second level :
           #T(n/2)=2(2T(n/8)+n/4)+n/2=4T(n/8)+n/2
    #substitute this into the first level:
           #T(n)=2(4T(n/8)+n/2)+n=8T(n/8)+n
   #After k levels, we can generalize the pattern:

          #T(n)=2kT(n/2k)+kn

#Now, we need to find when n/2k=1 to each the base cash. This gives us k = log2n.

   #Substitute k=log2n into the expression:
          #T(n)=2log2nT(1)+nlog2n

#simplify k = log2n into the expression:
           #T(n)=2log2nt(1)+nlog2nS

# if you have in initial condition T(0), you can substitute it in. if not, you canm leave the solution in this form. 
#So,the solution to the recurrence relation T(n)=2T(n-1)+1 using the recursive tree approach is T(n)=2nT(0)+(2n-1),where T(0)is the initial condition.
